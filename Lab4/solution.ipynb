# %% [markdown]
# # Contact Lenses Supply Chain Optimization

# %% [markdown]
# ## Modeling the Supply Chain
#
# ### Objective Function
#
# Minimize the total operating costs, which include:
#   - **Production Costs**: Cost of producing units at each manufacturing site.
#   - **Transportation Costs**: Cost of shipping products from manufacturing sites to distribution centers and warehouses.
#
# Decision Variables
#   - **Production Quantities**: Units of each product produced at each manufacturing site.
#   - **Transportation Quantities**: Units of each product shipped from manufacturing sites to distribution centers and warehouses.
#
# Constraints
#   1. **Production Capacity Constraints**: Each manufacturing site cannot produce more than its capacity.
#   2. **Demand Fulfillment Constraints**: Customer demand in each country must be met.
#   3. **Non-negativity Constraints**: Decision variables must be non-negative.

# %% [markdown]
# ## Implementing the Model

# %% [markdown]
# ### Import the necessary libraries.

# %%
import pandas as pd
import numpy as np
from pulp import *

# %% [markdown]
# ### Load the Data

# %%
products = pd.read_excel('Products.xlsx')
production = pd.read_excel('Production.xlsx')
demand = pd.read_excel('Demand.xlsx')
distribution = pd.read_excel('Distribution.xlsx')

# %% [markdown]
# ### Prepare the Data

# %% [markdown]
# **Products Data**

# %%
# Clean and process products data (remove the 'USD' string and convert to float)
products['cost_unit_production'] = products['cost_unit_production'].astype(str).str.replace(' USD', '').astype(float)

# %% [markdown]
# **Production Data**
#
# Create a list of production capacities.

# %%
# Production capacities
production_sites = production['Site Code'].tolist()
production_capacities = dict(zip(production['Site Code'], production['Unit Production']))

# %% [markdown]
# **Demand Data**

# %%
# Set index to Country_Code
demand.set_index('Country_Code', inplace=True)

# Demand for each product in each country
demand = demand.stack().reset_index()
demand.columns = ['Country_Code', 'Product_Code', 'Demand']

# %% [markdown]
# **Distribution Centers**

# %%
distribution_centers = distribution['Country_code'].unique().tolist()

# %% [markdown]
# ### Define the Optimization Model

# %%
# Create the LP Minimization problem
prob = LpProblem("Contact_Lenses_Supply_Chain_Optimization", LpMinimize)

# %% [markdown]
# ### Define Decision Variables

# %% [markdown]
# **Variables for Production Quantities**

# %%
# Decision variables for production quantities
production_vars = LpVariable.dicts("Production",
                                   ((site, product) for site in production_sites for product in products['Code']),
                                   lowBound=0,
                                   cat='Continuous')

# %% [markdown]
# **Variables for Transportation Quantities**

# %%
# Decision variables for transportation quantities
transport_vars = LpVariable.dicts("Transport",
                                  ((site, country, product) for site in production_sites
                                   for country in demand['Country_Code'].unique()
                                   for product in products['Code']),
                                  lowBound=0,
                                  cat='Continuous')

# %% [markdown]
# ### Define the Objective Function

# %% [markdown]
# We aim to minimize the total cost, which includes production and transportation costs.

# %%
# Production costs
production_costs = lpSum([production_vars[(site, product)] * products.loc[products['Code'] == product, 'cost_unit_production'].values[0]
                          for site in production_sites for product in products['Code']])

# Transportation costs
# For simplicity, assume a unit transportation cost (this can be replaced with actual costs if available)
unit_transport_cost = 0.1  # USD per unit per km

# Calculate distances between production sites and countries (requires coordinates)
# For this example, we'll assume a fixed cost
transportation_costs = lpSum([transport_vars[(site, country, product)] * unit_transport_cost
                              for site in production_sites
                              for country in demand['Country_Code'].unique()
                              for product in products['Code']])

# Total cost
total_cost = production_costs + transportation_costs

# Set the objective
prob += total_cost

# %% [markdown]
# ### Define Constraints

# %% [markdown]
# **Production Capacity Constraints**

# %%
for site in production_sites:
    prob += lpSum([production_vars[(site, product)] for product in products['Code']]) <= production_capacities[site], f"Capacity_{site}"

# %% [markdown]
# **Demand Fulfillment Constraints**

# %%
for index, row in demand.iterrows():
    country = row['Country_Code']
    product = row['Product_Code']
    demand_qty = row['Demand']
    prob += lpSum([transport_vars[(site, country, product)] for site in production_sites]) >= demand_qty, f"Demand_{country}_{product}"

# %% [markdown]
# **Link Between Production and Transportation**
#
# We need to ensure that the amount transported from a site does not exceed its production.

# %%
for site in production_sites:
    for product in products['Code']:
        prob += lpSum([transport_vars[(site, country, product)] for country in demand['Country_Code'].unique()]) <= production_vars[(site, product)], f"Transport_{site}_{product}"

# %% [markdown]
# ### Solve the Model

# %%
# Solve the optimization problem
prob.solve()

# Print the status
print(f"Status: {LpStatus[prob.status]}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/mateuszpolis/Documents/University/Semester 5/Mathematical Optimization Algorithms/.conda/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/8l/df7brwpx0vj8qwl22c82bj5w0000gn/T/b7ada75ec03746a6a7a778cc1a16c0ea-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/8l/df7brwpx0vj8qwl22c82bj5w0000gn/T/b7ada75ec03746a6a7a778cc1a16c0ea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 981 COLUMNS
# At line 11998 RHS
# At line 12975 BOUNDS
# At line 12976 ENDATA
# Problem MODEL has 976 rows, 3672 columns and 7344 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.4 - largest nonzero change 7.0735384e-06 ( 0.005696173%) - largest zero change 0
# 0  Obj 0 Primal inf 1.3421552e+13 (900)
# 10  Obj 1.2945402e+12 Primal inf 1.3421528e+13 (917)
# 83  Obj 2.6960414e+12 Primal inf 1.4542205e+13 (911)
# 93  Obj 2.7742666e+12 Primal inf 1.4874188e+13 (908)
# 152  Obj 3.1647425e+12 Primal inf 1.7913724e+13 (869)
# 189  Obj 3.4057346e+12 Primal inf 2.0285312e+13 (843)
# 283  Obj 4.0762245e+12 Primal inf 2.5142765e+13 (754)
# 377  Obj 4.5232883e+12 Primal inf 2.6530549e+13 (669)
# 471  Obj 4.7810287e+12 Primal inf 2.6575328e+13 (578)
# 508  Obj 4.8299453e+12 Primal inf 2.656202e+13 (545)
# 602  Obj 4.8709323e+12 Primal inf 2.6561434e+13 (488)
# 696  Obj 4.9025548e+12 Primal inf 2.6572478e+13 (429)
# 790  Obj 4.9295963e+12 Primal inf 2.6566777e+13 (364)
# 884  Obj 4.9564817e+12 Primal inf 2.657839e+13 (289)
# 978  Obj 4.9817093e+12 Primal inf 2.6563958e+13 (204)
# 1072  Obj 5.0022928e+12 Primal inf 2.6554664e+13 (118)
# 1166  Obj 5.0219524e+12 Primal inf 2.6553473e+13 (32)
# 1188  Obj 5.0249822e+12 Primal inf 2.6550251e+13 (11)
# 1190  Obj 5.0249905e+12 Primal inf 2.6051991e+13 (27)
# 1194  Obj 5.0249937e+12 Primal inf 2.6028059e+13 (26)
# 1195  Obj 5.0249967e+12 Primal inf 2.5867963e+13 (46)
# 1196  Obj 5.0249967e+12 Primal inf 2.7021557e+13 (46)
# 1198  Obj 5.0249985e+12 Primal inf 2.7022406e+13 (46)
# 1220  Obj 5.0249992e+12 Primal inf 2.7213531e+13 (23)
# 1231  Obj 5.0249993e+12 Primal inf 2.7238117e+13 (12)
# 1232  Obj 5.0249993e+12 Primal inf 2.7228117e+13 (12)
# 1232  Obj 5.0249993e+12 Primal inf 2.7228117e+13 (12)
# 1232  Obj 5.0248516e+12 Primal inf 8.8653879e+13 (262)
# 1232  Obj 5.0241133e+12 Primal inf 5.5865388e+14 (262)
# 1232  Obj 5.0204219e+12 Primal inf 2.9086539e+15 (262)
# 1232  Obj 5.0019645e+12 Primal inf 1.4658654e+16 (262)
# 1232  Obj 5.024848e+12 Primal inf 4.5097112e+13 (16) Dual inf 1.797e+13 (1824)
# 1326  Obj 5.024848e+12 Primal inf 1.6405452e+13 (17) Dual inf 2.3900024e+12 (1886)
# 1420  Obj 5.024848e+12 Primal inf 1.4655493e+13 (10) Dual inf 1.0800011e+12 (2076)
# 1490  Obj 5.024848e+12 Primal inf 1.3421409e+13 (1) Dual inf 0.00075656475 (2673)
# Primal infeasible - objective value 5.024848e+12
# PrimalInfeasible objective 5.024848e+12 - 1490 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Infeasible

# %% [markdown]
# ### Extract and Display the Results

# %%
# Production Plan
print("\nProduction Plan:")
for v in prob.variables():
    if "Production" in v.name and v.varValue > 0:
        print(f"{v.name} = {v.varValue}")

# Transportation Plan
print("\nTransportation Plan:")
for v in prob.variables():
    if "Transport" in v.name and v.varValue > 0:
        print(f"{v.name} = {v.varValue}")

# Total Cost
print(f"\nTotal Operating Cost = ${value(prob.objective):,.2f}")
# Out:
# Production Plan:
# Production_('KRCH',_'DA_Classic') = 1482446500000.0
# Production_('KRCH',_'DA_Economy') = 1605090900000.0
# Production_('KRCH',_'DA_Prem') = 1611169900000.0
# Production_('KRCH',_'DM_Classic') = 1456893900000.0
# Production_('KRCH',_'DM_Economy') = 101414590000.0
# Production_('KRCH',_'DM_Prem') = 1609320700000.0
# Production_('KRCH',_'DS_Classic') = 1636948500000.0
# Production_('KRCH',_'DS_Economy') = 1585550800000.0
# Production_('KRCH',_'DS_Prem') = 1450555200000.0
# Production_('KRCH',_'MA_Classic') = 94317167000.0
# Production_('KRCH',_'MA_Economy') = 103757980000.0
# Production_('KRCH',_'MA_Prem') = 103210750000.0
# Production_('KRCH',_'MM_Classic') = 98150625000.0
# Production_('KRCH',_'MM_Economy') = 95798533000.0
# Production_('KRCH',_'MM_Prem') = 97540484000.0
# Production_('KRCH',_'MS_Classic') = 96991883000.0
# Production_('KRCH',_'MS_Economy') = 98488498000.0
# Production_('KRCH',_'MS_Prem') = 93786952000.0
# Production_('PLLU',_'DM_Prem') = 37298613.0
# Production_('TRME',_'DM_Prem') = 40168561.0
# Production_('USAM',_'DM_Classic') = 41134963.0
#
# Transportation Plan:
# Transport_('KRCH',_'Other_Countries',_'DA_Classic') = 700337810000.0
# Transport_('KRCH',_'Other_Countries',_'DA_Economy') = 794073770000.0
# Transport_('KRCH',_'Other_Countries',_'DA_Prem') = 910421610000.0
# Transport_('KRCH',_'Other_Countries',_'DM_Classic') = 791672040000.0
# Transport_('KRCH',_'Other_Countries',_'DM_Economy') = 52283616000.0
# Transport_('KRCH',_'Other_Countries',_'DM_Prem') = 798446500000.0
# Transport_('KRCH',_'Other_Countries',_'DS_Classic') = 783315210000.0
# Transport_('KRCH',_'Other_Countries',_'DS_Economy') = 806711130000.0
# Transport_('KRCH',_'Other_Countries',_'DS_Prem') = 782093170000.0
# Transport_('KRCH',_'Other_Countries',_'MA_Classic') = 49284042000.0
# Transport_('KRCH',_'Other_Countries',_'MA_Economy') = 51804982000.0
# Transport_('KRCH',_'Other_Countries',_'MA_Prem') = 54412157000.0
# Transport_('KRCH',_'Other_Countries',_'MM_Classic') = 50148586000.0
# Transport_('KRCH',_'Other_Countries',_'MM_Economy') = 47928530000.0
# Transport_('KRCH',_'Other_Countries',_'MM_Prem') = 50308148000.0
# Transport_('KRCH',_'Other_Countries',_'MS_Classic') = 50576759000.0
# Transport_('KRCH',_'Other_Countries',_'MS_Economy') = 51072198000.0
# Transport_('KRCH',_'Other_Countries',_'MS_Prem') = 49828107000.0
# Transport_('KRCH',_'_AR',_'DA_Classic') = 12038391000.0
# Transport_('KRCH',_'_AR',_'DA_Economy') = 19047107000.0
# Transport_('KRCH',_'_AR',_'DA_Prem') = 17957539000.0
# Transport_('KRCH',_'_AR',_'DM_Classic') = 2292737500.0
# Transport_('KRCH',_'_AR',_'DM_Economy') = 1068979000.0
# Transport_('KRCH',_'_AR',_'DM_Prem') = 17833239000.0
# Transport_('KRCH',_'_AR',_'DS_Classic') = 5766425500.0
# Transport_('KRCH',_'_AR',_'DS_Economy') = 13678314000.0
# Transport_('KRCH',_'_AR',_'DS_Prem') = 4772786200.0
# Transport_('KRCH',_'_AR',_'MA_Classic') = 531753330.0
# Transport_('KRCH',_'_AR',_'MA_Economy') = 1041344500.0
# Transport_('KRCH',_'_AR',_'MA_Prem') = 600027170.0
# Transport_('KRCH',_'_AR',_'MM_Classic') = 1087029200.0
# Transport_('KRCH',_'_AR',_'MM_Economy') = 630940330.0
# Transport_('KRCH',_'_AR',_'MM_Prem') = 763393890.0
# Transport_('KRCH',_'_AR',_'MS_Classic') = 1344014400.0
# Transport_('KRCH',_'_AR',_'MS_Economy') = 1168252900.0
# Transport_('KRCH',_'_AR',_'MS_Prem') = 1117651400.0
# Transport_('KRCH',_'_AT',_'DA_Classic') = 27423336000.0
# Transport_('KRCH',_'_AT',_'DA_Economy') = 29531824000.0
# Transport_('KRCH',_'_AT',_'DA_Prem') = 1844273800.0
# Transport_('KRCH',_'_AT',_'DM_Classic') = 15699094000.0
# Transport_('KRCH',_'_AT',_'DM_Economy') = 852711950.0
# Transport_('KRCH',_'_AT',_'DM_Prem') = 25397601000.0
# Transport_('KRCH',_'_AT',_'DS_Classic') = 2105498700.0
# Transport_('KRCH',_'_AT',_'DS_Economy') = 18054845000.0
# Transport_('KRCH',_'_AT',_'DS_Prem') = 16852760000.0
# Transport_('KRCH',_'_AT',_'MA_Classic') = 968625850.0
# Transport_('KRCH',_'_AT',_'MA_Economy') = 1218443100.0
# Transport_('KRCH',_'_AT',_'MA_Prem') = 637926180.0
# Transport_('KRCH',_'_AT',_'MM_Classic') = 848437060.0
# Transport_('KRCH',_'_AT',_'MM_Economy') = 723294210.0
# Transport_('KRCH',_'_AT',_'MM_Prem') = 1367804600.0
# Transport_('KRCH',_'_AT',_'MS_Classic') = 718892920.0
# Transport_('KRCH',_'_AT',_'MS_Economy') = 716291330.0
# Transport_('KRCH',_'_AT',_'MS_Prem') = 611943900.0
# Transport_('KRCH',_'_AU',_'DA_Classic') = 29126858000.0
# Transport_('KRCH',_'_AU',_'DA_Economy') = 14028637000.0
# Transport_('KRCH',_'_AU',_'DA_Prem') = 23687735000.0
# Transport_('KRCH',_'_AU',_'DM_Classic') = 15926072000.0
# Transport_('KRCH',_'_AU',_'DM_Economy') = 1366041000.0
# Transport_('KRCH',_'_AU',_'DM_Prem') = 12380266000.0
# Transport_('KRCH',_'_AU',_'DS_Classic') = 29075076000.0
# Transport_('KRCH',_'_AU',_'DS_Economy') = 13412544000.0
# Transport_('KRCH',_'_AU',_'DS_Prem') = 16605894000.0
# Transport_('KRCH',_'_AU',_'MA_Classic') = 582088820.0
# Transport_('KRCH',_'_AU',_'MA_Economy') = 1208067300.0
# Transport_('KRCH',_'_AU',_'MA_Prem') = 1277032400.0
# Transport_('KRCH',_'_AU',_'MM_Classic') = 1013061700.0
# Transport_('KRCH',_'_AU',_'MM_Economy') = 1361313300.0
# Transport_('KRCH',_'_AU',_'MM_Prem') = 1285378700.0
# Transport_('KRCH',_'_AU',_'MS_Classic') = 1098247900.0
# Transport_('KRCH',_'_AU',_'MS_Economy') = 1359796800.0
# Transport_('KRCH',_'_AU',_'MS_Prem') = 575645460.0
# Transport_('KRCH',_'_BE',_'DA_Classic') = 26353038000.0
# Transport_('KRCH',_'_BE',_'DA_Economy') = 15186168000.0
# Transport_('KRCH',_'_BE',_'DA_Prem') = 1443748500.0
# Transport_('KRCH',_'_BE',_'DM_Classic') = 21212522000.0
# Transport_('KRCH',_'_BE',_'DM_Economy') = 861884410.0
# Transport_('KRCH',_'_BE',_'DM_Prem') = 11624655000.0
# Transport_('KRCH',_'_BE',_'DS_Classic') = 23750118000.0
# Transport_('KRCH',_'_BE',_'DS_Economy') = 15013956000.0
# Transport_('KRCH',_'_BE',_'DS_Prem') = 24968023000.0
# Transport_('KRCH',_'_BE',_'MA_Classic') = 785581600.0
# Transport_('KRCH',_'_BE',_'MA_Economy') = 930671630.0
# Transport_('KRCH',_'_BE',_'MA_Prem') = 921995590.0
# Transport_('KRCH',_'_BE',_'MM_Classic') = 705400040.0
# Transport_('KRCH',_'_BE',_'MM_Economy') = 1322057000.0
# Transport_('KRCH',_'_BE',_'MM_Prem') = 836176940.0
# Transport_('KRCH',_'_BE',_'MS_Classic') = 966979280.0
# Transport_('KRCH',_'_BE',_'MS_Economy') = 934000230.0
# Transport_('KRCH',_'_BE',_'MS_Prem') = 708717270.0
# Transport_('KRCH',_'_BR',_'DA_Classic') = 22711095000.0
# Transport_('KRCH',_'_BR',_'DA_Economy') = 17316772000.0
# Transport_('KRCH',_'_BR',_'DA_Prem') = 21100876000.0
# Transport_('KRCH',_'_BR',_'DM_Classic') = 9653526300.0
# Transport_('KRCH',_'_BR',_'DM_Economy') = 1458219500.0
# Transport_('KRCH',_'_BR',_'DM_Prem') = 22892478000.0
# Transport_('KRCH',_'_BR',_'DS_Classic') = 19015556000.0
# Transport_('KRCH',_'_BR',_'DS_Economy') = 29789303000.0
# Transport_('KRCH',_'_BR',_'DS_Prem') = 12393536000.0
# Transport_('KRCH',_'_BR',_'MA_Classic') = 1152274700.0
# Transport_('KRCH',_'_BR',_'MA_Economy') = 633351960.0
# Transport_('KRCH',_'_BR',_'MA_Prem') = 696611040.0
# Transport_('KRCH',_'_BR',_'MM_Classic') = 686680960.0
# Transport_('KRCH',_'_BR',_'MM_Economy') = 1061765100.0
# Transport_('KRCH',_'_BR',_'MM_Prem') = 733791170.0
# Transport_('KRCH',_'_BR',_'MS_Classic') = 1390598900.0
# Transport_('KRCH',_'_BR',_'MS_Economy') = 583821990.0
# Transport_('KRCH',_'_BR',_'MS_Prem') = 980032440.0
# Transport_('KRCH',_'_CA',_'DA_Classic') = 9984283600.0
# Transport_('KRCH',_'_CA',_'DA_Economy') = 29107396000.0
# Transport_('KRCH',_'_CA',_'DA_Prem') = 3108019200.0
# Transport_('KRCH',_'_CA',_'DM_Classic') = 3836952400.0
# Transport_('KRCH',_'_CA',_'DM_Economy') = 1043188000.0
# Transport_('KRCH',_'_CA',_'DM_Prem') = 3752618400.0
# Transport_('KRCH',_'_CA',_'DS_Classic') = 23585415000.0
# Transport_('KRCH',_'_CA',_'DS_Economy') = 29780646000.0
# Transport_('KRCH',_'_CA',_'DS_Prem') = 17829622000.0
# Transport_('KRCH',_'_CA',_'MA_Classic') = 1028607000.0
# Transport_('KRCH',_'_CA',_'MA_Economy') = 1190308600.0
# Transport_('KRCH',_'_CA',_'MA_Prem') = 1455099100.0
# Transport_('KRCH',_'_CA',_'MM_Classic') = 1206597600.0
# Transport_('KRCH',_'_CA',_'MM_Economy') = 959821670.0
# Transport_('KRCH',_'_CA',_'MM_Prem') = 1110694700.0
# Transport_('KRCH',_'_CA',_'MS_Classic') = 1393423000.0
# Transport_('KRCH',_'_CA',_'MS_Economy') = 1421880600.0
# Transport_('KRCH',_'_CA',_'MS_Prem') = 568454590.0
# Transport_('KRCH',_'_CH',_'DA_Classic') = 14916205000.0
# Transport_('KRCH',_'_CH',_'DA_Economy') = 6568281000.0
# Transport_('KRCH',_'_CH',_'DA_Prem') = 2153366100.0
# Transport_('KRCH',_'_CH',_'DM_Classic') = 17706302000.0
# Transport_('KRCH',_'_CH',_'DM_Economy') = 814932010.0
# Transport_('KRCH',_'_CH',_'DM_Prem') = 14021208000.0
# Transport_('KRCH',_'_CH',_'DS_Classic') = 2107032200.0
# Transport_('KRCH',_'_CH',_'DS_Economy') = 10222805000.0
# Transport_('KRCH',_'_CH',_'DS_Prem') = 26362519000.0
# Transport_('KRCH',_'_CH',_'MA_Classic') = 1172235300.0
# Transport_('KRCH',_'_CH',_'MA_Economy') = 1086912000.0
# Transport_('KRCH',_'_CH',_'MA_Prem') = 1252871600.0
# Transport_('KRCH',_'_CH',_'MM_Classic') = 1050668900.0
# Transport_('KRCH',_'_CH',_'MM_Economy') = 1194995600.0
# Transport_('KRCH',_'_CH',_'MM_Prem') = 888883370.0
# Transport_('KRCH',_'_CH',_'MS_Classic') = 679243950.0
# Transport_('KRCH',_'_CH',_'MS_Economy') = 1038254500.0
# Transport_('KRCH',_'_CH',_'MS_Prem') = 992738120.0
# Transport_('KRCH',_'_CL',_'DA_Classic') = 5001656900.0
# Transport_('KRCH',_'_CL',_'DA_Economy') = 16864159000.0
# Transport_('KRCH',_'_CL',_'DA_Prem') = 17521983000.0
# Transport_('KRCH',_'_CL',_'DM_Classic') = 11475573000.0
# Transport_('KRCH',_'_CL',_'DM_Economy') = 1458827000.0
# Transport_('KRCH',_'_CL',_'DM_Prem') = 17221712000.0
# Transport_('KRCH',_'_CL',_'DS_Classic') = 20206964000.0
# Transport_('KRCH',_'_CL',_'DS_Economy') = 27678833000.0
# Transport_('KRCH',_'_CL',_'DS_Prem') = 9258734900.0
# Transport_('KRCH',_'_CL',_'MA_Classic') = 1207240900.0
# Transport_('KRCH',_'_CL',_'MA_Economy') = 1064301900.0
# Transport_('KRCH',_'_CL',_'MA_Prem') = 761573000.0
# Transport_('KRCH',_'_CL',_'MM_Classic') = 904349880.0
# Transport_('KRCH',_'_CL',_'MM_Economy') = 1036995900.0
# Transport_('KRCH',_'_CL',_'MM_Prem') = 644954730.0
# Transport_('KRCH',_'_CL',_'MS_Classic') = 633998660.0
# Transport_('KRCH',_'_CL',_'MS_Economy') = 1449918400.0
# Transport_('KRCH',_'_CL',_'MS_Prem') = 1042021800.0
# Transport_('KRCH',_'_CN',_'DA_Classic') = 18835915000.0
# Transport_('KRCH',_'_CN',_'DA_Economy') = 12239159000.0
# Transport_('KRCH',_'_CN',_'DA_Prem') = 22767136000.0
# Transport_('KRCH',_'_CN',_'DM_Classic') = 20432843000.0
# Transport_('KRCH',_'_CN',_'DM_Economy') = 997775440.0
# Transport_('KRCH',_'_CN',_'DM_Prem') = 29376499000.0
# Transport_('KRCH',_'_CN',_'DS_Classic') = 23888926000.0
# Transport_('KRCH',_'_CN',_'DS_Economy') = 22398343000.0
# Transport_('KRCH',_'_CN',_'DS_Prem') = 7208504900.0
# Transport_('KRCH',_'_CN',_'MA_Classic') = 1418135500.0
# Transport_('KRCH',_'_CN',_'MA_Economy') = 855451950.0
# Transport_('KRCH',_'_CN',_'MA_Prem') = 1208335300.0
# Transport_('KRCH',_'_CN',_'MM_Classic') = 758696780.0
# Transport_('KRCH',_'_CN',_'MM_Economy') = 1106999400.0
# Transport_('KRCH',_'_CN',_'MM_Prem') = 1234993600.0
# Transport_('KRCH',_'_CN',_'MS_Classic') = 621411300.0
# Transport_('KRCH',_'_CN',_'MS_Economy') = 1449084400.0
# Transport_('KRCH',_'_CN',_'MS_Prem') = 542988000.0
# Transport_('KRCH',_'_CO',_'DA_Classic') = 27060465000.0
# Transport_('KRCH',_'_CO',_'DA_Economy') = 24592891000.0
# Transport_('KRCH',_'_CO',_'DA_Prem') = 10595320000.0
# Transport_('KRCH',_'_CO',_'DM_Classic') = 10213291000.0
# Transport_('KRCH',_'_CO',_'DM_Economy') = 1432346300.0
# Transport_('KRCH',_'_CO',_'DM_Prem') = 29970116000.0
# Transport_('KRCH',_'_CO',_'DS_Classic') = 25749122000.0
# Transport_('KRCH',_'_CO',_'DS_Economy') = 14145942000.0
# Transport_('KRCH',_'_CO',_'DS_Prem') = 11514390000.0
# Transport_('KRCH',_'_CO',_'MA_Classic') = 706023090.0
# Transport_('KRCH',_'_CO',_'MA_Economy') = 606618840.0
# Transport_('KRCH',_'_CO',_'MA_Prem') = 636149160.0
# Transport_('KRCH',_'_CO',_'MM_Classic') = 646871750.0
# Transport_('KRCH',_'_CO',_'MM_Economy') = 1112945800.0
# Transport_('KRCH',_'_CO',_'MM_Prem') = 737860480.0
# Transport_('KRCH',_'_CO',_'MS_Classic') = 1092776300.0
# Transport_('KRCH',_'_CO',_'MS_Economy') = 1292593900.0
# Transport_('KRCH',_'_CO',_'MS_Prem') = 547302320.0
# Transport_('KRCH',_'_DE',_'DA_Classic') = 12999778000.0
# Transport_('KRCH',_'_DE',_'DA_Economy') = 29613136000.0
# Transport_('KRCH',_'_DE',_'DA_Prem') = 3141053000.0
# Transport_('KRCH',_'_DE',_'DM_Classic') = 14649536000.0
# Transport_('KRCH',_'_DE',_'DM_Economy') = 1122171400.0
# Transport_('KRCH',_'_DE',_'DM_Prem') = 6195249300.0
# Transport_('KRCH',_'_DE',_'DS_Classic') = 29813569000.0
# Transport_('KRCH',_'_DE',_'DS_Economy') = 3665292900.0
# Transport_('KRCH',_'_DE',_'DS_Prem') = 6313874800.0
# Transport_('KRCH',_'_DE',_'MA_Classic') = 799357490.0
# Transport_('KRCH',_'_DE',_'MA_Economy') = 931103230.0
# Transport_('KRCH',_'_DE',_'MA_Prem') = 675304120.0
# Transport_('KRCH',_'_DE',_'MM_Classic') = 1012793100.0
# Transport_('KRCH',_'_DE',_'MM_Economy') = 650794560.0
# Transport_('KRCH',_'_DE',_'MM_Prem') = 1099146900.0
# Transport_('KRCH',_'_DE',_'MS_Classic') = 1467102500.0
# Transport_('KRCH',_'_DE',_'MS_Economy') = 1475033200.0
# Transport_('KRCH',_'_DE',_'MS_Prem') = 919332750.0
# Transport_('KRCH',_'_DK',_'DA_Classic') = 10666088000.0
# Transport_('KRCH',_'_DK',_'DA_Economy') = 15826554000.0
# Transport_('KRCH',_'_DK',_'DA_Prem') = 8992065000.0
# Transport_('KRCH',_'_DK',_'DM_Classic') = 27882449000.0
# Transport_('KRCH',_'_DK',_'DM_Economy') = 670934140.0
# Transport_('KRCH',_'_DK',_'DM_Prem') = 19172635000.0
# Transport_('KRCH',_'_DK',_'DS_Classic') = 18722909000.0
# Transport_('KRCH',_'_DK',_'DS_Economy') = 14884762000.0
# Transport_('KRCH',_'_DK',_'DS_Prem') = 13118249000.0
# Transport_('KRCH',_'_DK',_'MA_Classic') = 1099819400.0
# Transport_('KRCH',_'_DK',_'MA_Economy') = 1049549900.0
# Transport_('KRCH',_'_DK',_'MA_Prem') = 1487976100.0
# Transport_('KRCH',_'_DK',_'MM_Classic') = 683109270.0
# Transport_('KRCH',_'_DK',_'MM_Economy') = 1355248500.0
# Transport_('KRCH',_'_DK',_'MM_Prem') = 1207187600.0
# Transport_('KRCH',_'_DK',_'MS_Classic') = 1046024400.0
# Transport_('KRCH',_'_DK',_'MS_Economy') = 815654330.0
# Transport_('KRCH',_'_DK',_'MS_Prem') = 1271641500.0
# Transport_('KRCH',_'_EG',_'DA_Classic') = 4611564900.0
# Transport_('KRCH',_'_EG',_'DA_Economy') = 11321648000.0
# Transport_('KRCH',_'_EG',_'DA_Prem') = 1336649600.0
# Transport_('KRCH',_'_EG',_'DM_Classic') = 24842797000.0
# Transport_('KRCH',_'_EG',_'DM_Economy') = 562350040.0
# Transport_('KRCH',_'_EG',_'DM_Prem') = 11573325000.0
# Transport_('KRCH',_'_EG',_'DS_Classic') = 24125982000.0
# Transport_('KRCH',_'_EG',_'DS_Economy') = 5340749000.0
# Transport_('KRCH',_'_EG',_'DS_Prem') = 13463733000.0
# Transport_('KRCH',_'_EG',_'MA_Classic') = 738434680.0
# Transport_('KRCH',_'_EG',_'MA_Economy') = 1323127800.0
# Transport_('KRCH',_'_EG',_'MA_Prem') = 569837460.0
# Transport_('KRCH',_'_EG',_'MM_Classic') = 581247110.0
# Transport_('KRCH',_'_EG',_'MM_Economy') = 1326126600.0
# Transport_('KRCH',_'_EG',_'MM_Prem') = 1381456500.0
# Transport_('KRCH',_'_EG',_'MS_Classic') = 932855840.0
# Transport_('KRCH',_'_EG',_'MS_Economy') = 846704100.0
# Transport_('KRCH',_'_EG',_'MS_Prem') = 1199747400.0
# Transport_('KRCH',_'_ES',_'DA_Classic') = 15882288000.0
# Transport_('KRCH',_'_ES',_'DA_Economy') = 13296948000.0
# Transport_('KRCH',_'_ES',_'DA_Prem') = 22755055000.0
# Transport_('KRCH',_'_ES',_'DM_Classic') = 4678543200.0
# Transport_('KRCH',_'_ES',_'DM_Economy') = 785965540.0
# Transport_('KRCH',_'_ES',_'DM_Prem') = 27470914000.0
# Transport_('KRCH',_'_ES',_'DS_Classic') = 3825325400.0
# Transport_('KRCH',_'_ES',_'DS_Economy') = 21477093000.0
# Transport_('KRCH',_'_ES',_'DS_Prem') = 7421384400.0
# Transport_('KRCH',_'_ES',_'MA_Classic') = 736307770.0
# Transport_('KRCH',_'_ES',_'MA_Economy') = 1149457900.0
# Transport_('KRCH',_'_ES',_'MA_Prem') = 1453138800.0
# Transport_('KRCH',_'_ES',_'MM_Classic') = 691698950.0
# Transport_('KRCH',_'_ES',_'MM_Economy') = 741820970.0
# Transport_('KRCH',_'_ES',_'MM_Prem') = 1460704000.0
# Transport_('KRCH',_'_ES',_'MS_Classic') = 703027270.0
# Transport_('KRCH',_'_ES',_'MS_Economy') = 859604900.0
# Transport_('KRCH',_'_ES',_'MS_Prem') = 1217845700.0
# Transport_('KRCH',_'_FI',_'DA_Classic') = 13420193000.0
# Transport_('KRCH',_'_FI',_'DA_Economy') = 10819915000.0
# Transport_('KRCH',_'_FI',_'DA_Prem') = 18970400000.0
# Transport_('KRCH',_'_FI',_'DM_Classic') = 25086654000.0
# Transport_('KRCH',_'_FI',_'DM_Economy') = 684581470.0
# Transport_('KRCH',_'_FI',_'DM_Prem') = 20747986000.0
# Transport_('KRCH',_'_FI',_'DS_Classic') = 14421954000.0
# Transport_('KRCH',_'_FI',_'DS_Economy') = 24781200000.0
# Transport_('KRCH',_'_FI',_'DS_Prem') = 15198684000.0
# Transport_('KRCH',_'_FI',_'MA_Classic') = 1021469100.0
# Transport_('KRCH',_'_FI',_'MA_Economy') = 1232067200.0
# Transport_('KRCH',_'_FI',_'MA_Prem') = 823545300.0
# Transport_('KRCH',_'_FI',_'MM_Classic') = 783791070.0
# Transport_('KRCH',_'_FI',_'MM_Economy') = 651563660.0
# Transport_('KRCH',_'_FI',_'MM_Prem') = 1106819100.0
# Transport_('KRCH',_'_FI',_'MS_Classic') = 542168050.0
# Transport_('KRCH',_'_FI',_'MS_Economy') = 690135370.0
# Transport_('KRCH',_'_FI',_'MS_Prem') = 1014778700.0
# Transport_('KRCH',_'_FR',_'DA_Classic') = 26083699000.0
# Transport_('KRCH',_'_FR',_'DA_Economy') = 26187716000.0
# Transport_('KRCH',_'_FR',_'DA_Prem') = 27222887000.0
# Transport_('KRCH',_'_FR',_'DM_Classic') = 23909462000.0
# Transport_('KRCH',_'_FR',_'DM_Economy') = 505532240.0
# Transport_('KRCH',_'_FR',_'DM_Prem') = 24666404000.0
# Transport_('KRCH',_'_FR',_'DS_Classic') = 22830995000.0
# Transport_('KRCH',_'_FR',_'DS_Economy') = 9000229300.0
# Transport_('KRCH',_'_FR',_'DS_Prem') = 24474575000.0
# Transport_('KRCH',_'_FR',_'MA_Classic') = 1226396600.0
# Transport_('KRCH',_'_FR',_'MA_Economy') = 1284332100.0
# Transport_('KRCH',_'_FR',_'MA_Prem') = 1126571100.0
# Transport_('KRCH',_'_FR',_'MM_Classic') = 771322710.0
# Transport_('KRCH',_'_FR',_'MM_Economy') = 1263060400.0
# Transport_('KRCH',_'_FR',_'MM_Prem') = 1239681000.0
# Transport_('KRCH',_'_FR',_'MS_Classic') = 815578990.0
# Transport_('KRCH',_'_FR',_'MS_Economy') = 1492563400.0
# Transport_('KRCH',_'_FR',_'MS_Prem') = 825517560.0
# Transport_('KRCH',_'_GB',_'DA_Classic') = 1857693300.0
# Transport_('KRCH',_'_GB',_'DA_Economy') = 9942330200.0
# Transport_('KRCH',_'_GB',_'DA_Prem') = 24251670000.0
# Transport_('KRCH',_'_GB',_'DM_Classic') = 3450932300.0
# Transport_('KRCH',_'_GB',_'DM_Economy') = 1092802800.0
# Transport_('KRCH',_'_GB',_'DM_Prem') = 23649593000.0
# Transport_('KRCH',_'_GB',_'DS_Classic') = 21521021000.0
# Transport_('KRCH',_'_GB',_'DS_Economy') = 22657791000.0
# Transport_('KRCH',_'_GB',_'DS_Prem') = 6276739700.0
# Transport_('KRCH',_'_GB',_'MA_Classic') = 693404690.0
# Transport_('KRCH',_'_GB',_'MA_Economy') = 643928910.0
# Transport_('KRCH',_'_GB',_'MA_Prem') = 951680560.0
# Transport_('KRCH',_'_GB',_'MM_Classic') = 993616460.0
# Transport_('KRCH',_'_GB',_'MM_Economy') = 1339513900.0
# Transport_('KRCH',_'_GB',_'MM_Prem') = 654017020.0
# Transport_('KRCH',_'_GB',_'MS_Classic') = 607066070.0
# Transport_('KRCH',_'_GB',_'MS_Economy') = 522755080.0
# Transport_('KRCH',_'_GB',_'MS_Prem') = 766008070.0
# Transport_('KRCH',_'_GR',_'DA_Classic') = 22763570000.0
# Transport_('KRCH',_'_GR',_'DA_Economy') = 14712086000.0
# Transport_('KRCH',_'_GR',_'DA_Prem') = 8765501900.0
# Transport_('KRCH',_'_GR',_'DM_Classic') = 9986732600.0
# Transport_('KRCH',_'_GR',_'DM_Economy') = 1386805400.0
# Transport_('KRCH',_'_GR',_'DM_Prem') = 21430352000.0
# Transport_('KRCH',_'_GR',_'DS_Classic') = 7899243200.0
# Transport_('KRCH',_'_GR',_'DS_Economy') = 5386459800.0
# Transport_('KRCH',_'_GR',_'DS_Prem') = 1336546500.0
# Transport_('KRCH',_'_GR',_'MA_Classic') = 863056400.0
# Transport_('KRCH',_'_GR',_'MA_Economy') = 521445140.0
# Transport_('KRCH',_'_GR',_'MA_Prem') = 1095484200.0
# Transport_('KRCH',_'_GR',_'MM_Classic') = 1409160500.0
# Transport_('KRCH',_'_GR',_'MM_Economy') = 647305770.0
# Transport_('KRCH',_'_GR',_'MM_Prem') = 915698310.0
# Transport_('KRCH',_'_GR',_'MS_Classic') = 1287883200.0
# Transport_('KRCH',_'_GR',_'MS_Economy') = 710337060.0
# Transport_('KRCH',_'_GR',_'MS_Prem') = 507282700.0
# Transport_('KRCH',_'_HU',_'DA_Classic') = 9932360400.0
# Transport_('KRCH',_'_HU',_'DA_Economy') = 11271753000.0
# Transport_('KRCH',_'_HU',_'DA_Prem') = 17387987000.0
# Transport_('KRCH',_'_HU',_'DM_Classic') = 9888269200.0
# Transport_('KRCH',_'_HU',_'DM_Economy') = 714783230.0
# Transport_('KRCH',_'_HU',_'DM_Prem') = 18991981000.0
# Transport_('KRCH',_'_HU',_'DS_Classic') = 4464546600.0
# Transport_('KRCH',_'_HU',_'DS_Economy') = 6026558400.0
# Transport_('KRCH',_'_HU',_'DS_Prem') = 6714504600.0
# Transport_('KRCH',_'_HU',_'MA_Classic') = 512637770.0
# Transport_('KRCH',_'_HU',_'MA_Economy') = 762568810.0
# Transport_('KRCH',_'_HU',_'MA_Prem') = 570656920.0
# Transport_('KRCH',_'_HU',_'MM_Classic') = 1249075000.0
# Transport_('KRCH',_'_HU',_'MM_Economy') = 916996000.0
# Transport_('KRCH',_'_HU',_'MM_Prem') = 607355770.0
# Transport_('KRCH',_'_HU',_'MS_Classic') = 1138853600.0
# Transport_('KRCH',_'_HU',_'MS_Economy') = 847423080.0
# Transport_('KRCH',_'_HU',_'MS_Prem') = 789107580.0
# Transport_('KRCH',_'_ID',_'DA_Classic') = 25499063000.0
# Transport_('KRCH',_'_ID',_'DA_Economy') = 6614025400.0
# Transport_('KRCH',_'_ID',_'DA_Prem') = 17950820000.0
# Transport_('KRCH',_'_ID',_'DM_Classic') = 16661504000.0
# Transport_('KRCH',_'_ID',_'DM_Economy') = 1102253500.0
# Transport_('KRCH',_'_ID',_'DM_Prem') = 10830463000.0
# Transport_('KRCH',_'_ID',_'DS_Classic') = 21707301000.0
# Transport_('KRCH',_'_ID',_'DS_Economy') = 7677001400.0
# Transport_('KRCH',_'_ID',_'DS_Prem') = 3115070400.0
# Transport_('KRCH',_'_ID',_'MA_Classic') = 1060973800.0
# Transport_('KRCH',_'_ID',_'MA_Economy') = 657697180.0
# Transport_('KRCH',_'_ID',_'MA_Prem') = 628391730.0
# Transport_('KRCH',_'_ID',_'MM_Classic') = 945523090.0
# Transport_('KRCH',_'_ID',_'MM_Economy') = 529433440.0
# Transport_('KRCH',_'_ID',_'MM_Prem') = 608269770.0
# Transport_('KRCH',_'_ID',_'MS_Classic') = 812748010.0
# Transport_('KRCH',_'_ID',_'MS_Economy') = 713302480.0
# Transport_('KRCH',_'_ID',_'MS_Prem') = 600087010.0
# Transport_('KRCH',_'_IE',_'DA_Classic') = 8492770400.0
# Transport_('KRCH',_'_IE',_'DA_Economy') = 19323162000.0
# Transport_('KRCH',_'_IE',_'DA_Prem') = 8126861100.0
# Transport_('KRCH',_'_IE',_'DM_Classic') = 8748536400.0
# Transport_('KRCH',_'_IE',_'DM_Economy') = 919049460.0
# Transport_('KRCH',_'_IE',_'DM_Prem') = 15777795000.0
# Transport_('KRCH',_'_IE',_'DS_Classic') = 7732284900.0
# Transport_('KRCH',_'_IE',_'DS_Economy') = 27170951000.0
# Transport_('KRCH',_'_IE',_'DS_Prem') = 7506458400.0
# Transport_('KRCH',_'_IE',_'MA_Classic') = 656468460.0
# Transport_('KRCH',_'_IE',_'MA_Economy') = 673784140.0
# Transport_('KRCH',_'_IE',_'MA_Prem') = 1489213900.0
# Transport_('KRCH',_'_IE',_'MM_Classic') = 853361420.0
# Transport_('KRCH',_'_IE',_'MM_Economy') = 1132343500.0
# Transport_('KRCH',_'_IE',_'MM_Prem') = 976175340.0
# Transport_('KRCH',_'_IE',_'MS_Classic') = 912924650.0
# Transport_('KRCH',_'_IE',_'MS_Economy') = 569419160.0
# Transport_('KRCH',_'_IE',_'MS_Prem') = 764823020.0
# Transport_('KRCH',_'_IL',_'DA_Classic') = 18219191000.0
# Transport_('KRCH',_'_IL',_'DA_Economy') = 27643609000.0
# Transport_('KRCH',_'_IL',_'DA_Prem') = 24156837000.0
# Transport_('KRCH',_'_IL',_'DM_Classic') = 15673337000.0
# Transport_('KRCH',_'_IL',_'DM_Economy') = 925333770.0
# Transport_('KRCH',_'_IL',_'DM_Prem') = 22045184000.0
# Transport_('KRCH',_'_IL',_'DS_Classic') = 12149966000.0
# Transport_('KRCH',_'_IL',_'DS_Economy') = 16835885000.0
# Transport_('KRCH',_'_IL',_'DS_Prem') = 21716339000.0
# Transport_('KRCH',_'_IL',_'MA_Classic') = 1037769100.0
# Transport_('KRCH',_'_IL',_'MA_Economy') = 1097754500.0
# Transport_('KRCH',_'_IL',_'MA_Prem') = 626291090.0
# Transport_('KRCH',_'_IL',_'MM_Classic') = 1438173200.0
# Transport_('KRCH',_'_IL',_'MM_Economy') = 967242760.0
# Transport_('KRCH',_'_IL',_'MM_Prem') = 798495020.0
# Transport_('KRCH',_'_IL',_'MS_Classic') = 1230291700.0
# Transport_('KRCH',_'_IL',_'MS_Economy') = 1388218000.0
# Transport_('KRCH',_'_IL',_'MS_Prem') = 626645580.0
# Transport_('KRCH',_'_IN',_'DA_Classic') = 14194624000.0
# Transport_('KRCH',_'_IN',_'DA_Economy') = 1674284200.0
# Transport_('KRCH',_'_IN',_'DA_Prem') = 29190583000.0
# Transport_('KRCH',_'_IN',_'DM_Classic') = 2650375600.0
# Transport_('KRCH',_'_IN',_'DM_Economy') = 596271170.0
# Transport_('KRCH',_'_IN',_'DM_Prem') = 25505011000.0
# Transport_('KRCH',_'_IN',_'DS_Classic') = 14368233000.0
# Transport_('KRCH',_'_IN',_'DS_Economy') = 24193585000.0
# Transport_('KRCH',_'_IN',_'DS_Prem') = 25562859000.0
# Transport_('KRCH',_'_IN',_'MA_Classic') = 1050129400.0
# Transport_('KRCH',_'_IN',_'MA_Economy') = 830361570.0
# Transport_('KRCH',_'_IN',_'MA_Prem') = 1135200800.0
# Transport_('KRCH',_'_IN',_'MM_Classic') = 1147110700.0
# Transport_('KRCH',_'_IN',_'MM_Economy') = 1318815300.0
# Transport_('KRCH',_'_IN',_'MM_Prem') = 860229620.0
# Transport_('KRCH',_'_IN',_'MS_Classic') = 725805670.0
# Transport_('KRCH',_'_IN',_'MS_Economy') = 975415930.0
# Transport_('KRCH',_'_IN',_'MS_Prem') = 1379648600.0
# Transport_('KRCH',_'_IT',_'DA_Classic') = 25214733000.0
# Transport_('KRCH',_'_IT',_'DA_Economy') = 22433778000.0
# Transport_('KRCH',_'_IT',_'DA_Prem') = 5011276600.0
# Transport_('KRCH',_'_IT',_'DM_Classic') = 5367165700.0
# Transport_('KRCH',_'_IT',_'DM_Economy') = 1492633000.0
# Transport_('KRCH',_'_IT',_'DM_Prem') = 13188758000.0
# Transport_('KRCH',_'_IT',_'DS_Classic') = 28004012000.0
# Transport_('KRCH',_'_IT',_'DS_Economy') = 9852607500.0
# Transport_('KRCH',_'_IT',_'DS_Prem') = 9992798300.0
# Transport_('KRCH',_'_IT',_'MA_Classic') = 1473844900.0
# Transport_('KRCH',_'_IT',_'MA_Economy') = 1237861900.0
# Transport_('KRCH',_'_IT',_'MA_Prem') = 1129014800.0
# Transport_('KRCH',_'_IT',_'MM_Classic') = 1223330200.0
# Transport_('KRCH',_'_IT',_'MM_Economy') = 1013900100.0
# Transport_('KRCH',_'_IT',_'MM_Prem') = 931402380.0
# Transport_('KRCH',_'_IT',_'MS_Classic') = 867977070.0
# Transport_('KRCH',_'_IT',_'MS_Economy') = 948371430.0
# Transport_('KRCH',_'_IT',_'MS_Prem') = 661114120.0
# Transport_('KRCH',_'_JP',_'DA_Classic') = 16146717000.0
# Transport_('KRCH',_'_JP',_'DA_Economy') = 12796033000.0
# Transport_('KRCH',_'_JP',_'DA_Prem') = 13048901000.0
# Transport_('KRCH',_'_JP',_'DM_Classic') = 8558082500.0
# Transport_('KRCH',_'_JP',_'DM_Economy') = 1343047100.0
# Transport_('KRCH',_'_JP',_'DM_Prem') = 12135697000.0
# Transport_('KRCH',_'_JP',_'DS_Classic') = 21658896000.0
# Transport_('KRCH',_'_JP',_'DS_Economy') = 8932428800.0
# Transport_('KRCH',_'_JP',_'DS_Prem') = 4228637400.0
# Transport_('KRCH',_'_JP',_'MA_Classic') = 1030911100.0
# Transport_('KRCH',_'_JP',_'MA_Economy') = 1207867200.0
# Transport_('KRCH',_'_JP',_'MA_Prem') = 966840180.0
# Transport_('KRCH',_'_JP',_'MM_Classic') = 729594110.0
# Transport_('KRCH',_'_JP',_'MM_Economy') = 671601370.0
# Transport_('KRCH',_'_JP',_'MM_Prem') = 900384520.0
# Transport_('KRCH',_'_JP',_'MS_Classic') = 1324800500.0
# Transport_('KRCH',_'_JP',_'MS_Economy') = 1052340100.0
# Transport_('KRCH',_'_JP',_'MS_Prem') = 559894900.0
# Transport_('KRCH',_'_KE',_'DA_Classic') = 20054105000.0
# Transport_('KRCH',_'_KE',_'DA_Economy') = 13039439000.0
# Transport_('KRCH',_'_KE',_'DA_Prem') = 17268531000.0
# Transport_('KRCH',_'_KE',_'DM_Classic') = 2773362600.0
# Transport_('KRCH',_'_KE',_'DM_Economy') = 919996620.0
# Transport_('KRCH',_'_KE',_'DM_Prem') = 29078600000.0
# Transport_('KRCH',_'_KE',_'DS_Classic') = 11775441000.0
# Transport_('KRCH',_'_KE',_'DS_Economy') = 25157978000.0
# Transport_('KRCH',_'_KE',_'DS_Prem') = 12353311000.0
# Transport_('KRCH',_'_KE',_'MA_Classic') = 783858820.0
# Transport_('KRCH',_'_KE',_'MA_Economy') = 1191516800.0
# Transport_('KRCH',_'_KE',_'MA_Prem') = 1181025100.0
# Transport_('KRCH',_'_KE',_'MM_Classic') = 560583730.0
# Transport_('KRCH',_'_KE',_'MM_Economy') = 833788830.0
# Transport_('KRCH',_'_KE',_'MM_Prem') = 1266795400.0
# Transport_('KRCH',_'_KE',_'MS_Classic') = 1390097300.0
# Transport_('KRCH',_'_KE',_'MS_Economy') = 1491733000.0
# Transport_('KRCH',_'_KE',_'MS_Prem') = 1413566900.0
# Transport_('KRCH',_'_KR',_'DA_Classic') = 10450483000.0
# Transport_('KRCH',_'_KR',_'DA_Economy') = 18333093000.0
# Transport_('KRCH',_'_KR',_'DA_Prem') = 20159349000.0
# Transport_('KRCH',_'_KR',_'DM_Classic') = 20282804000.0
# Transport_('KRCH',_'_KR',_'DM_Economy') = 1002101700.0
# Transport_('KRCH',_'_KR',_'DM_Prem') = 25377798000.0
# Transport_('KRCH',_'_KR',_'DS_Classic') = 14243630000.0
# Transport_('KRCH',_'_KR',_'DS_Economy') = 2757586000.0
# Transport_('KRCH',_'_KR',_'DS_Prem') = 23567813000.0
# Transport_('KRCH',_'_KR',_'MA_Classic') = 1203616600.0
# Transport_('KRCH',_'_KR',_'MA_Economy') = 1061001800.0
# Transport_('KRCH',_'_KR',_'MA_Prem') = 1368801600.0
# Transport_('KRCH',_'_KR',_'MM_Classic') = 1300403700.0
# Transport_('KRCH',_'_KR',_'MM_Economy') = 1253650300.0
# Transport_('KRCH',_'_KR',_'MM_Prem') = 1310181000.0
# Transport_('KRCH',_'_KR',_'MS_Classic') = 538553100.0
# Transport_('KRCH',_'_KR',_'MS_Economy') = 555075260.0
# Transport_('KRCH',_'_KR',_'MS_Prem') = 845404010.0
# Transport_('KRCH',_'_MX',_'DA_Classic') = 14748453000.0
# Transport_('KRCH',_'_MX',_'DA_Economy') = 19842580000.0
# Transport_('KRCH',_'_MX',_'DA_Prem') = 14383360000.0
# Transport_('KRCH',_'_MX',_'DM_Classic') = 21217690000.0
# Transport_('KRCH',_'_MX',_'DM_Economy') = 825774080.0
# Transport_('KRCH',_'_MX',_'DM_Prem') = 11386728000.0
# Transport_('KRCH',_'_MX',_'DS_Classic') = 16815644000.0
# Transport_('KRCH',_'_MX',_'DS_Economy') = 20929089000.0
# Transport_('KRCH',_'_MX',_'DS_Prem') = 15098321000.0
# Transport_('KRCH',_'_MX',_'MA_Classic') = 1073183600.0
# Transport_('KRCH',_'_MX',_'MA_Economy') = 1044490900.0
# Transport_('KRCH',_'_MX',_'MA_Prem') = 1378503400.0
# Transport_('KRCH',_'_MX',_'MM_Classic') = 1135000200.0
# Transport_('KRCH',_'_MX',_'MM_Economy') = 950274870.0
# Transport_('KRCH',_'_MX',_'MM_Prem') = 1026868000.0
# Transport_('KRCH',_'_MX',_'MS_Classic') = 1142585700.0
# Transport_('KRCH',_'_MX',_'MS_Economy') = 715387510.0
# Transport_('KRCH',_'_MX',_'MS_Prem') = 789770270.0
# Transport_('KRCH',_'_MY',_'DA_Classic') = 14097568000.0
# Transport_('KRCH',_'_MY',_'DA_Economy') = 14797593000.0
# Transport_('KRCH',_'_MY',_'DA_Prem') = 8173193900.0
# Transport_('KRCH',_'_MY',_'DM_Classic') = 9841029300.0
# Transport_('KRCH',_'_MY',_'DM_Economy') = 639283030.0
# Transport_('KRCH',_'_MY',_'DM_Prem') = 6448752600.0
# Transport_('KRCH',_'_MY',_'DS_Classic') = 14584316000.0
# Transport_('KRCH',_'_MY',_'DS_Economy') = 24984167000.0
# Transport_('KRCH',_'_MY',_'DS_Prem') = 10600801000.0
# Transport_('KRCH',_'_MY',_'MA_Classic') = 1052774700.0
# Transport_('KRCH',_'_MY',_'MA_Economy') = 1327460100.0
# Transport_('KRCH',_'_MY',_'MA_Prem') = 767557640.0
# Transport_('KRCH',_'_MY',_'MM_Classic') = 919011650.0
# Transport_('KRCH',_'_MY',_'MM_Economy') = 775464260.0
# Transport_('KRCH',_'_MY',_'MM_Prem') = 870338600.0
# Transport_('KRCH',_'_MY',_'MS_Classic') = 1069688600.0
# Transport_('KRCH',_'_MY',_'MS_Economy') = 1086544800.0
# Transport_('KRCH',_'_MY',_'MS_Prem') = 1284935500.0
# Transport_('KRCH',_'_NG',_'DA_Classic') = 7183851700.0
# Transport_('KRCH',_'_NG',_'DA_Economy') = 21475880000.0
# Transport_('KRCH',_'_NG',_'DA_Prem') = 1572581400.0
# Transport_('KRCH',_'_NG',_'DM_Classic') = 7967473800.0
# Transport_('KRCH',_'_NG',_'DM_Economy') = 638909560.0
# Transport_('KRCH',_'_NG',_'DM_Prem') = 25833140000.0
# Transport_('KRCH',_'_NG',_'DS_Classic') = 14664521000.0
# Transport_('KRCH',_'_NG',_'DS_Economy') = 29653941000.0
# Transport_('KRCH',_'_NG',_'DS_Prem') = 8843603200.0
# Transport_('KRCH',_'_NG',_'MA_Classic') = 687403940.0
# Transport_('KRCH',_'_NG',_'MA_Economy') = 1088271600.0
# Transport_('KRCH',_'_NG',_'MA_Prem') = 870761200.0
# Transport_('KRCH',_'_NG',_'MM_Classic') = 1310958100.0
# Transport_('KRCH',_'_NG',_'MM_Economy') = 1187913800.0
# Transport_('KRCH',_'_NG',_'MM_Prem') = 1167516800.0
# Transport_('KRCH',_'_NG',_'MS_Classic') = 1133497200.0
# Transport_('KRCH',_'_NG',_'MS_Economy') = 961433970.0
# Transport_('KRCH',_'_NG',_'MS_Prem') = 552178650.0
# Transport_('KRCH',_'_NL',_'DA_Classic') = 24477738000.0
# Transport_('KRCH',_'_NL',_'DA_Economy') = 25217544000.0
# Transport_('KRCH',_'_NL',_'DA_Prem') = 13985335000.0
# Transport_('KRCH',_'_NL',_'DM_Classic') = 1292816600.0
# Transport_('KRCH',_'_NL',_'DM_Economy') = 1111691000.0
# Transport_('KRCH',_'_NL',_'DM_Prem') = 12356322000.0
# Transport_('KRCH',_'_NL',_'DS_Classic') = 4154342400.0
# Transport_('KRCH',_'_NL',_'DS_Economy') = 19387000000.0
# Transport_('KRCH',_'_NL',_'DS_Prem') = 1765512300.0
# Transport_('KRCH',_'_NL',_'MA_Classic') = 664707800.0
# Transport_('KRCH',_'_NL',_'MA_Economy') = 833032520.0
# Transport_('KRCH',_'_NL',_'MA_Prem') = 694668870.0
# Transport_('KRCH',_'_NL',_'MM_Classic') = 869295370.0
# Transport_('KRCH',_'_NL',_'MM_Economy') = 601324890.0
# Transport_('KRCH',_'_NL',_'MM_Prem') = 509800460.0
# Transport_('KRCH',_'_NL',_'MS_Classic') = 683838940.0
# Transport_('KRCH',_'_NL',_'MS_Economy') = 874080010.0
# Transport_('KRCH',_'_NL',_'MS_Prem') = 866476190.0
# Transport_('KRCH',_'_NO',_'DA_Classic') = 7304990500.0
# Transport_('KRCH',_'_NO',_'DA_Economy') = 15480822000.0
# Transport_('KRCH',_'_NO',_'DA_Prem') = 6089728400.0
# Transport_('KRCH',_'_NO',_'DM_Classic') = 26496910000.0
# Transport_('KRCH',_'_NO',_'DM_Economy') = 1182787700.0
# Transport_('KRCH',_'_NO',_'DM_Prem') = 1305228600.0
# Transport_('KRCH',_'_NO',_'DS_Classic') = 3826890000.0
# Transport_('KRCH',_'_NO',_'DS_Economy') = 5135823700.0
# Transport_('KRCH',_'_NO',_'DS_Prem') = 17232876000.0
# Transport_('KRCH',_'_NO',_'MA_Classic') = 1337142000.0
# Transport_('KRCH',_'_NO',_'MA_Economy') = 1147826900.0
# Transport_('KRCH',_'_NO',_'MA_Prem') = 1423229400.0
# Transport_('KRCH',_'_NO',_'MM_Classic') = 830033300.0
# Transport_('KRCH',_'_NO',_'MM_Economy') = 667489830.0
# Transport_('KRCH',_'_NO',_'MM_Prem') = 1332397500.0
# Transport_('KRCH',_'_NO',_'MS_Classic') = 1023694800.0
# Transport_('KRCH',_'_NO',_'MS_Economy') = 1059269700.0
# Transport_('KRCH',_'_NO',_'MS_Prem') = 1039874500.0
# Transport_('KRCH',_'_NZ',_'DA_Classic') = 28412298000.0
# Transport_('KRCH',_'_NZ',_'DA_Economy') = 13025268000.0
# Transport_('KRCH',_'_NZ',_'DA_Prem') = 12257136000.0
# Transport_('KRCH',_'_NZ',_'DM_Classic') = 18569233000.0
# Transport_('KRCH',_'_NZ',_'DM_Economy') = 1496946200.0
# Transport_('KRCH',_'_NZ',_'DM_Prem') = 18396729000.0
# Transport_('KRCH',_'_NZ',_'DS_Classic') = 27685290000.0
# Transport_('KRCH',_'_NZ',_'DS_Economy') = 18963103000.0
# Transport_('KRCH',_'_NZ',_'DS_Prem') = 14543757000.0
# Transport_('KRCH',_'_NZ',_'MA_Classic') = 1339730900.0
# Transport_('KRCH',_'_NZ',_'MA_Economy') = 1495888800.0
# Transport_('KRCH',_'_NZ',_'MA_Prem') = 1350158400.0
# Transport_('KRCH',_'_NZ',_'MM_Classic') = 834437040.0
# Transport_('KRCH',_'_NZ',_'MM_Economy') = 1063736400.0
# Transport_('KRCH',_'_NZ',_'MM_Prem') = 1091140700.0
# Transport_('KRCH',_'_NZ',_'MS_Classic') = 788243380.0
# Transport_('KRCH',_'_NZ',_'MS_Economy') = 1274460800.0
# Transport_('KRCH',_'_NZ',_'MS_Prem') = 1312663600.0
# Transport_('KRCH',_'_PE',_'DA_Classic') = 28202344000.0
# Transport_('KRCH',_'_PE',_'DA_Economy') = 2020158400.0
# Transport_('KRCH',_'_PE',_'DA_Prem') = 21516543000.0
# Transport_('KRCH',_'_PE',_'DM_Classic') = 17843835000.0
# Transport_('KRCH',_'_PE',_'DM_Economy') = 958191150.0
# Transport_('KRCH',_'_PE',_'DM_Prem') = 24708758000.0
# Transport_('KRCH',_'_PE',_'DS_Classic') = 28802197000.0
# Transport_('KRCH',_'_PE',_'DS_Economy') = 9861740000.0
# Transport_('KRCH',_'_PE',_'DS_Prem') = 28610931000.0
# Transport_('KRCH',_'_PE',_'MA_Classic') = 1118025200.0
# Transport_('KRCH',_'_PE',_'MA_Economy') = 1354102500.0
# Transport_('KRCH',_'_PE',_'MA_Prem') = 521389660.0
# Transport_('KRCH',_'_PE',_'MM_Classic') = 620301580.0
# Transport_('KRCH',_'_PE',_'MM_Economy') = 1166300200.0
# Transport_('KRCH',_'_PE',_'MM_Prem') = 551162970.0
# Transport_('KRCH',_'_PE',_'MS_Classic') = 533703800.0
# Transport_('KRCH',_'_PE',_'MS_Economy') = 1469989800.0
# Transport_('KRCH',_'_PE',_'MS_Prem') = 851618860.0
# Transport_('KRCH',_'_PH',_'DA_Classic') = 7079886200.0
# Transport_('KRCH',_'_PH',_'DA_Economy') = 14851397000.0
# Transport_('KRCH',_'_PH',_'DA_Prem') = 23223877000.0
# Transport_('KRCH',_'_PH',_'DM_Classic') = 6642233100.0
# Transport_('KRCH',_'_PH',_'DM_Economy') = 842641480.0
# Transport_('KRCH',_'_PH',_'DM_Prem') = 1105491700.0
# Transport_('KRCH',_'_PH',_'DS_Classic') = 23715243000.0
# Transport_('KRCH',_'_PH',_'DS_Economy') = 26403281000.0
# Transport_('KRCH',_'_PH',_'DS_Prem') = 22707069000.0
# Transport_('KRCH',_'_PH',_'MA_Classic') = 863539800.0
# Transport_('KRCH',_'_PH',_'MA_Economy') = 1157554600.0
# Transport_('KRCH',_'_PH',_'MA_Prem') = 805853630.0
# Transport_('KRCH',_'_PH',_'MM_Classic') = 1082510200.0
# Transport_('KRCH',_'_PH',_'MM_Economy') = 843736090.0
# Transport_('KRCH',_'_PH',_'MM_Prem') = 1014014900.0
# Transport_('KRCH',_'_PH',_'MS_Classic') = 627244250.0
# Transport_('KRCH',_'_PH',_'MS_Economy') = 1054969500.0
# Transport_('KRCH',_'_PH',_'MS_Prem') = 1193677400.0
# Transport_('KRCH',_'_PK',_'DA_Classic') = 3153907200.0
# Transport_('KRCH',_'_PK',_'DA_Economy') = 27618613000.0
# Transport_('KRCH',_'_PK',_'DA_Prem') = 3102061600.0
# Transport_('KRCH',_'_PK',_'DM_Classic') = 5771099700.0
# Transport_('KRCH',_'_PK',_'DM_Economy') = 1021114400.0
# Transport_('KRCH',_'_PK',_'DM_Prem') = 7002687300.0
# Transport_('KRCH',_'_PK',_'DS_Classic') = 23273230000.0
# Transport_('KRCH',_'_PK',_'DS_Economy') = 20658071000.0
# Transport_('KRCH',_'_PK',_'DS_Prem') = 2162848400.0
# Transport_('KRCH',_'_PK',_'MA_Classic') = 1118041100.0
# Transport_('KRCH',_'_PK',_'MA_Economy') = 891675140.0
# Transport_('KRCH',_'_PK',_'MA_Prem') = 1326396700.0
# Transport_('KRCH',_'_PK',_'MM_Classic') = 900976680.0
# Transport_('KRCH',_'_PK',_'MM_Economy') = 965799590.0
# Transport_('KRCH',_'_PK',_'MM_Prem') = 1002083800.0
# Transport_('KRCH',_'_PK',_'MS_Classic') = 1429840900.0
# Transport_('KRCH',_'_PK',_'MS_Economy') = 909644460.0
# Transport_('KRCH',_'_PK',_'MS_Prem') = 1186172200.0
# Transport_('KRCH',_'_PL',_'DA_Classic') = 17518379000.0
# Transport_('KRCH',_'_PL',_'DA_Economy') = 19313444000.0
# Transport_('KRCH',_'_PL',_'DA_Prem') = 15104420000.0
# Transport_('KRCH',_'_PL',_'DM_Classic') = 13423997000.0
# Transport_('KRCH',_'_PL',_'DM_Economy') = 1214830300.0
# Transport_('KRCH',_'_PL',_'DM_Prem') = 8291699500.0
# Transport_('KRCH',_'_PL',_'DS_Classic') = 928698720.0
# Transport_('KRCH',_'_PL',_'DS_Economy') = 17045965000.0
# Transport_('KRCH',_'_PL',_'DS_Prem') = 11727973000.0
# Transport_('KRCH',_'_PL',_'MA_Classic') = 674438740.0
# Transport_('KRCH',_'_PL',_'MA_Economy') = 1276430300.0
# Transport_('KRCH',_'_PL',_'MA_Prem') = 880480470.0
# Transport_('KRCH',_'_PL',_'MM_Classic') = 1174062600.0
# Transport_('KRCH',_'_PL',_'MM_Economy') = 904255930.0
# Transport_('KRCH',_'_PL',_'MM_Prem') = 718137190.0
# Transport_('KRCH',_'_PL',_'MS_Classic') = 1456207800.0
# Transport_('KRCH',_'_PL',_'MS_Economy') = 745466870.0
# Transport_('KRCH',_'_PL',_'MS_Prem') = 670951020.0
# Transport_('KRCH',_'_PT',_'DA_Classic') = 1035438200.0
# Transport_('KRCH',_'_PT',_'DA_Economy') = 7744415900.0
# Transport_('KRCH',_'_PT',_'DA_Prem') = 3955127300.0
# Transport_('KRCH',_'_PT',_'DM_Classic') = 28111661000.0
# Transport_('KRCH',_'_PT',_'DM_Economy') = 730119040.0
# Transport_('KRCH',_'_PT',_'DM_Prem') = 9300625300.0
# Transport_('KRCH',_'_PT',_'DS_Classic') = 29264367000.0
# Transport_('KRCH',_'_PT',_'DS_Economy') = 23295451000.0
# Transport_('KRCH',_'_PT',_'DS_Prem') = 26490099000.0
# Transport_('KRCH',_'_PT',_'MA_Classic') = 1048439300.0
# Transport_('KRCH',_'_PT',_'MA_Economy') = 1113675600.0
# Transport_('KRCH',_'_PT',_'MA_Prem') = 1293831800.0
# Transport_('KRCH',_'_PT',_'MM_Classic') = 609247260.0
# Transport_('KRCH',_'_PT',_'MM_Economy') = 868936650.0
# Transport_('KRCH',_'_PT',_'MM_Prem') = 620865120.0
# Transport_('KRCH',_'_PT',_'MS_Classic') = 890753130.0
# Transport_('KRCH',_'_PT',_'MS_Economy') = 600394430.0
# Transport_('KRCH',_'_PT',_'MS_Prem') = 1004507800.0
# Transport_('KRCH',_'_QA',_'DA_Classic') = 29590864000.0
# Transport_('KRCH',_'_QA',_'DA_Economy') = 10382967000.0
# Transport_('KRCH',_'_QA',_'DA_Prem') = 22123024000.0
# Transport_('KRCH',_'_QA',_'DM_Classic') = 15249756000.0
# Transport_('KRCH',_'_QA',_'DM_Economy') = 677453660.0
# Transport_('KRCH',_'_QA',_'DM_Prem') = 12128523000.0
# Transport_('KRCH',_'_QA',_'DS_Classic') = 17267933000.0
# Transport_('KRCH',_'_QA',_'DS_Economy') = 20300380000.0
# Transport_('KRCH',_'_QA',_'DS_Prem') = 23648901000.0
# Transport_('KRCH',_'_QA',_'MA_Classic') = 609745590.0
# Transport_('KRCH',_'_QA',_'MA_Economy') = 1413879300.0
# Transport_('KRCH',_'_QA',_'MA_Prem') = 575698260.0
# Transport_('KRCH',_'_QA',_'MM_Classic') = 1355259800.0
# Transport_('KRCH',_'_QA',_'MM_Economy') = 790636130.0
# Transport_('KRCH',_'_QA',_'MM_Prem') = 1434849400.0
# Transport_('KRCH',_'_QA',_'MS_Classic') = 671730060.0
# Transport_('KRCH',_'_QA',_'MS_Economy') = 1335118800.0
# Transport_('KRCH',_'_QA',_'MS_Prem') = 1006602400.0
# Transport_('KRCH',_'_RU',_'DA_Classic') = 12616669000.0
# Transport_('KRCH',_'_RU',_'DA_Economy') = 8659751500.0
# Transport_('KRCH',_'_RU',_'DA_Prem') = 3969690000.0
# Transport_('KRCH',_'_RU',_'DM_Classic') = 29557751000.0
# Transport_('KRCH',_'_RU',_'DM_Economy') = 796436130.0
# Transport_('KRCH',_'_RU',_'DM_Prem') = 18091587000.0
# Transport_('KRCH',_'_RU',_'DS_Classic') = 12684640000.0
# Transport_('KRCH',_'_RU',_'DS_Economy') = 13469885000.0
# Transport_('KRCH',_'_RU',_'DS_Prem') = 21671611000.0
# Transport_('KRCH',_'_RU',_'MA_Classic') = 1025610000.0
# Transport_('KRCH',_'_RU',_'MA_Economy') = 954707240.0
# Transport_('KRCH',_'_RU',_'MA_Prem') = 602909260.0
# Transport_('KRCH',_'_RU',_'MM_Classic') = 1325733300.0
# Transport_('KRCH',_'_RU',_'MM_Economy') = 1000226800.0
# Transport_('KRCH',_'_RU',_'MM_Prem') = 1167507900.0
# Transport_('KRCH',_'_RU',_'MS_Classic') = 677428000.0
# Transport_('KRCH',_'_RU',_'MS_Economy') = 785728920.0
# Transport_('KRCH',_'_RU',_'MS_Prem') = 773637270.0
# Transport_('KRCH',_'_SA',_'DA_Classic') = 28584151000.0
# Transport_('KRCH',_'_SA',_'DA_Economy') = 28643346000.0
# Transport_('KRCH',_'_SA',_'DA_Prem') = 13875355000.0
# Transport_('KRCH',_'_SA',_'DM_Classic') = 8063058400.0
# Transport_('KRCH',_'_SA',_'DM_Economy') = 806078170.0
# Transport_('KRCH',_'_SA',_'DM_Prem') = 17766624000.0
# Transport_('KRCH',_'_SA',_'DS_Classic') = 26936823000.0
# Transport_('KRCH',_'_SA',_'DS_Economy') = 17384580000.0
# Transport_('KRCH',_'_SA',_'DS_Prem') = 29627842000.0
# Transport_('KRCH',_'_SA',_'MA_Classic') = 562724000.0
# Transport_('KRCH',_'_SA',_'MA_Economy') = 1356135500.0
# Transport_('KRCH',_'_SA',_'MA_Prem') = 861247460.0
# Transport_('KRCH',_'_SA',_'MM_Classic') = 605738450.0
# Transport_('KRCH',_'_SA',_'MM_Economy') = 1246969100.0
# Transport_('KRCH',_'_SA',_'MM_Prem') = 511893640.0
# Transport_('KRCH',_'_SA',_'MS_Classic') = 562986920.0
# Transport_('KRCH',_'_SA',_'MS_Economy') = 810702560.0
# Transport_('KRCH',_'_SA',_'MS_Prem') = 955894240.0
# Transport_('KRCH',_'_SE',_'DA_Classic') = 4986304900.0
# Transport_('KRCH',_'_SE',_'DA_Economy') = 29269098000.0
# Transport_('KRCH',_'_SE',_'DA_Prem') = 28622693000.0
# Transport_('KRCH',_'_SE',_'DM_Classic') = 19502642000.0
# Transport_('KRCH',_'_SE',_'DM_Economy') = 1146406900.0
# Transport_('KRCH',_'_SE',_'DM_Prem') = 1035612700.0
# Transport_('KRCH',_'_SE',_'DS_Classic') = 25310975000.0
# Transport_('KRCH',_'_SE',_'DS_Economy') = 3049126300.0
# Transport_('KRCH',_'_SE',_'DS_Prem') = 22212775000.0
# Transport_('KRCH',_'_SE',_'MA_Classic') = 606093690.0
# Transport_('KRCH',_'_SE',_'MA_Economy') = 1029103300.0
# Transport_('KRCH',_'_SE',_'MA_Prem') = 950703440.0
# Transport_('KRCH',_'_SE',_'MM_Classic') = 1388910000.0
# Transport_('KRCH',_'_SE',_'MM_Economy') = 868998210.0
# Transport_('KRCH',_'_SE',_'MM_Prem') = 887851440.0
# Transport_('KRCH',_'_SE',_'MS_Classic') = 1158283000.0
# Transport_('KRCH',_'_SE',_'MS_Economy') = 556836360.0
# Transport_('KRCH',_'_SE',_'MS_Prem') = 1030491200.0
# Transport_('KRCH',_'_SG',_'DA_Classic') = 28763467000.0
# Transport_('KRCH',_'_SG',_'DA_Economy') = 13490636000.0
# Transport_('KRCH',_'_SG',_'DA_Prem') = 3372725900.0
# Transport_('KRCH',_'_SG',_'DM_Classic') = 2533786200.0
# Transport_('KRCH',_'_SG',_'DM_Economy') = 1100279000.0
# Transport_('KRCH',_'_SG',_'DM_Prem') = 14756634000.0
# Transport_('KRCH',_'_SG',_'DS_Classic') = 28379832000.0
# Transport_('KRCH',_'_SG',_'DS_Economy') = 822698780.0
# Transport_('KRCH',_'_SG',_'DS_Prem') = 16625907000.0
# Transport_('KRCH',_'_SG',_'MA_Classic') = 1331175000.0
# Transport_('KRCH',_'_SG',_'MA_Economy') = 1289159500.0
# Transport_('KRCH',_'_SG',_'MA_Prem') = 972876440.0
# Transport_('KRCH',_'_SG',_'MM_Classic') = 988954350.0
# Transport_('KRCH',_'_SG',_'MM_Economy') = 1350433800.0
# Transport_('KRCH',_'_SG',_'MM_Prem') = 884006170.0
# Transport_('KRCH',_'_SG',_'MS_Classic') = 955653200.0
# Transport_('KRCH',_'_SG',_'MS_Economy') = 1131972900.0
# Transport_('KRCH',_'_SG',_'MS_Prem') = 1218813800.0
# Transport_('KRCH',_'_TH',_'DA_Classic') = 2003435700.0
# Transport_('KRCH',_'_TH',_'DA_Economy') = 4503482600.0
# Transport_('KRCH',_'_TH',_'DA_Prem') = 9620812200.0
# Transport_('KRCH',_'_TH',_'DM_Classic') = 22631304000.0
# Transport_('KRCH',_'_TH',_'DM_Economy') = 901624870.0
# Transport_('KRCH',_'_TH',_'DM_Prem') = 16748043000.0
# Transport_('KRCH',_'_TH',_'DS_Classic') = 4072928700.0
# Transport_('KRCH',_'_TH',_'DS_Economy') = 8382001100.0
# Transport_('KRCH',_'_TH',_'DS_Prem') = 8328999100.0
# Transport_('KRCH',_'_TH',_'MA_Classic') = 1199586800.0
# Transport_('KRCH',_'_TH',_'MA_Economy') = 1161652200.0
# Transport_('KRCH',_'_TH',_'MA_Prem') = 1471063600.0
# Transport_('KRCH',_'_TH',_'MM_Classic') = 706616180.0
# Transport_('KRCH',_'_TH',_'MM_Economy') = 1099455900.0
# Transport_('KRCH',_'_TH',_'MM_Prem') = 1293775400.0
# Transport_('KRCH',_'_TH',_'MS_Classic') = 1320489100.0
# Transport_('KRCH',_'_TH',_'MS_Economy') = 589440480.0
# Transport_('KRCH',_'_TH',_'MS_Prem') = 671653650.0
# Transport_('KRCH',_'_TR',_'DA_Classic') = 6266598300.0
# Transport_('KRCH',_'_TR',_'DA_Economy') = 20580323000.0
# Transport_('KRCH',_'_TR',_'DA_Prem') = 14046720000.0
# Transport_('KRCH',_'_TR',_'DM_Classic') = 2478868000.0
# Transport_('KRCH',_'_TR',_'DM_Economy') = 1451401400.0
# Transport_('KRCH',_'_TR',_'DM_Prem') = 11512096000.0
# Transport_('KRCH',_'_TR',_'DS_Classic') = 19954540000.0
# Transport_('KRCH',_'_TR',_'DS_Economy') = 4850520900.0
# Transport_('KRCH',_'_TR',_'DS_Prem') = 8274190600.0
# Transport_('KRCH',_'_TR',_'MA_Classic') = 513198990.0
# Transport_('KRCH',_'_TR',_'MA_Economy') = 958960440.0
# Transport_('KRCH',_'_TR',_'MA_Prem') = 1411291900.0
# Transport_('KRCH',_'_TR',_'MM_Classic') = 1367482400.0
# Transport_('KRCH',_'_TR',_'MM_Economy') = 591882610.0
# Transport_('KRCH',_'_TR',_'MM_Prem') = 624840240.0
# Transport_('KRCH',_'_TR',_'MS_Classic') = 610469910.0
# Transport_('KRCH',_'_TR',_'MS_Economy') = 1225138200.0
# Transport_('KRCH',_'_TR',_'MS_Prem') = 817947520.0
# Transport_('KRCH',_'_UA',_'DA_Classic') = 24348780000.0
# Transport_('KRCH',_'_UA',_'DA_Economy') = 23015632000.0
# Transport_('KRCH',_'_UA',_'DA_Prem') = 28805370000.0
# Transport_('KRCH',_'_UA',_'DM_Classic') = 3858143400.0
# Transport_('KRCH',_'_UA',_'DM_Economy') = 1461399300.0
# Transport_('KRCH',_'_UA',_'DM_Prem') = 13194718000.0
# Transport_('KRCH',_'_UA',_'DS_Classic') = 9853906500.0
# Transport_('KRCH',_'_UA',_'DS_Economy') = 23881976000.0
# Transport_('KRCH',_'_UA',_'DS_Prem') = 12901953000.0
# Transport_('KRCH',_'_UA',_'MA_Classic') = 524231090.0
# Transport_('KRCH',_'_UA',_'MA_Economy') = 954849510.0
# Transport_('KRCH',_'_UA',_'MA_Prem') = 866885540.0
# Transport_('KRCH',_'_UA',_'MM_Classic') = 1081832500.0
# Transport_('KRCH',_'_UA',_'MM_Economy') = 1012661900.0
# Transport_('KRCH',_'_UA',_'MM_Prem') = 1240044200.0
# Transport_('KRCH',_'_UA',_'MS_Classic') = 924253280.0
# Transport_('KRCH',_'_UA',_'MS_Economy') = 601477710.0
# Transport_('KRCH',_'_UA',_'MS_Prem') = 724360810.0
# Transport_('KRCH',_'_US',_'DA_Classic') = 3596577100.0
# Transport_('KRCH',_'_US',_'DA_Economy') = 9219680100.0
# Transport_('KRCH',_'_US',_'DA_Prem') = 18447849000.0
# Transport_('KRCH',_'_US',_'DM_Classic') = 5024170700.0
# Transport_('KRCH',_'_US',_'DM_Economy') = 569008370.0
# Transport_('KRCH',_'_US',_'DM_Prem') = 10108029000.0
# Transport_('KRCH',_'_US',_'DS_Classic') = 28051261000.0
# Transport_('KRCH',_'_US',_'DS_Economy') = 21308887000.0
# Transport_('KRCH',_'_US',_'DS_Prem') = 1820444800.0
# Transport_('KRCH',_'_US',_'MA_Classic') = 916301250.0
# Transport_('KRCH',_'_US',_'MA_Economy') = 1309714000.0
# Transport_('KRCH',_'_US',_'MA_Prem') = 759343360.0
# Transport_('KRCH',_'_US',_'MM_Classic') = 941164650.0
# Transport_('KRCH',_'_US',_'MM_Economy') = 798146350.0
# Transport_('KRCH',_'_US',_'MM_Prem') = 522413550.0
# Transport_('KRCH',_'_US',_'MS_Classic') = 629811130.0
# Transport_('KRCH',_'_US',_'MS_Economy') = 935690670.0
# Transport_('KRCH',_'_US',_'MS_Prem') = 596080440.0
# Transport_('KRCH',_'_VN',_'DA_Classic') = 17434382000.0
# Transport_('KRCH',_'_VN',_'DA_Economy') = 6420723600.0
# Transport_('KRCH',_'_VN',_'DA_Prem') = 22906671000.0
# Transport_('KRCH',_'_VN',_'DM_Classic') = 27485952000.0
# Transport_('KRCH',_'_VN',_'DM_Economy') = 967372100.0
# Transport_('KRCH',_'_VN',_'DM_Prem') = 27976558000.0
# Transport_('KRCH',_'_VN',_'DS_Classic') = 9526353300.0
# Transport_('KRCH',_'_VN',_'DS_Economy') = 9540286600.0
# Transport_('KRCH',_'_VN',_'DS_Prem') = 8531151700.0
# Transport_('KRCH',_'_VN',_'MA_Classic') = 682162300.0
# Transport_('KRCH',_'_VN',_'MA_Economy') = 758484870.0
# Transport_('KRCH',_'_VN',_'MA_Prem') = 1022971900.0
# Transport_('KRCH',_'_VN',_'MM_Classic') = 1495867000.0
# Transport_('KRCH',_'_VN',_'MM_Economy') = 1137447000.0
# Transport_('KRCH',_'_VN',_'MM_Prem') = 576108970.0
# Transport_('KRCH',_'_VN',_'MS_Classic') = 864351990.0
# Transport_('KRCH',_'_VN',_'MS_Economy') = 554723660.0
# Transport_('KRCH',_'_VN',_'MS_Prem') = 1462577200.0
# Transport_('KRCH',_'_ZA',_'DA_Classic') = 20762395000.0
# Transport_('KRCH',_'_ZA',_'DA_Economy') = 26111873000.0
# Transport_('KRCH',_'_ZA',_'DA_Prem') = 21677552000.0
# Transport_('KRCH',_'_ZA',_'DM_Classic') = 18118988000.0
# Transport_('KRCH',_'_ZA',_'DM_Economy') = 1409707000.0
# Transport_('KRCH',_'_ZA',_'DM_Prem') = 29111472000.0
# Transport_('KRCH',_'_ZA',_'DS_Classic') = 29363901000.0
# Transport_('KRCH',_'_ZA',_'DS_Economy') = 9558006200.0
# Transport_('KRCH',_'_ZA',_'DS_Prem') = 4906101100.0
# Transport_('KRCH',_'_ZA',_'MA_Classic') = 543846820.0
# Transport_('KRCH',_'_ZA',_'MA_Economy') = 1345042500.0
# Transport_('KRCH',_'_ZA',_'MA_Prem') = 1264178300.0
# Transport_('KRCH',_'_ZA',_'MM_Classic') = 1176958400.0
# Transport_('KRCH',_'_ZA',_'MM_Economy') = 853578000.0
# Transport_('KRCH',_'_ZA',_'MM_Prem') = 1256787400.0
# Transport_('KRCH',_'_ZA',_'MS_Classic') = 977025100.0
# Transport_('KRCH',_'_ZA',_'MS_Economy') = 769847410.0
# Transport_('KRCH',_'_ZA',_'MS_Prem') = 898018640.0
# Transport_('PLLU',_'_ZA',_'DM_Prem') = 37298613.0
# Transport_('TRME',_'_NG',_'DM_Prem') = 40168561.0
# Transport_('USAM',_'_ZA',_'DM_Classic') = 41134963.0
#
# Total Operating Cost = $5,024,848,036,558.40
